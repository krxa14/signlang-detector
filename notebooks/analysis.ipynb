# %% [markdown]
# # Model comparison
# Reads `results/evaluation.csv`.

# %%
import pandas as pd, matplotlib.pyplot as plt, pathlib
csv = pathlib.Path('../results/evaluation.csv')
if csv.exists():
    df = pd.read_csv(csv); print(df)
    df.plot(x='Model', y=['accuracy','f1'], kind='bar', figsize=(8,4)); plt.show()
else:
    print('Run scripts/evaluate.py first')
